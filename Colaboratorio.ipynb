# %% [markdown]
# <a href="https://colab.research.google.com/github/santiago-perezvicchi10/Modulo1/blob/main/Colaboratorio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Este es mi primer cuaderno
#
# ##Aqui voy a mezclar codigo markdown con operaciones matematica
#
# - Sumar
# - Restar
# - Multiplicar
# - Dividir

# %%
a=3
b=5
a+b
# Out:
# [1] 8

# %% [markdown]
# Este es mi primer cuaderno
# Aqui voy a mezclar el codigo markdown con operanciones matematica
#
#
#
# *   Sumar
# *   Restar
# *   Multiplicar
# *   Dividir

# %%
a = 1:100
b = a*a

plot (a, b, main = "Presion del gas critico", xlab = "Volumen", ylab = "Presion", type = "b", col = "blue")
# Out:
# Plot with title “Presion del gas critico”
